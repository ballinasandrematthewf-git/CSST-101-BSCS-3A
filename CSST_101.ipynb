# %% [markdown]
# My First R Program

# %% [markdown]
# 1. print

# %%
print("I love jonh Rayson Yatco")

cat ("R" , "program")

print(paste("A","Program"))
# Out:
# [1] "I love jonh Rayson Yatco"
# R program[1] "A Program"

# %% [markdown]
# 2. variables and data types

# %%
myString <- "I love jonh Rayson Yatco"
print (myString)

wholeNum <- 10
floatingNum <- 9.9
isBool <- TRUE

class(wholeNum)
class(floatingNum)
class(isBool)
# Out:
# [1] "I love jonh Rayson Yatco"
# [1] "numeric"
# [1] "numeric"
# [1] "logical"

# %% [markdown]
# 3. Numerical Operators

# %%
a <- 10
b <- 49

add <- b + a
sub <- b - a
mult <- b * a
div <- b / a
mod <- b %% a
Exp <- b ^ a

print(add)
print(sub)
print(mult)
print(div)
print(mod)
print(exp)
# Out:
# [1] 59
# [1] 39
# [1] 490
# [1] 4.9
# [1] 9
# function (x)  .Primitive("exp")

# %% [markdown]
# 4.

# %% [markdown]
# 4. User Input

# %%
name <- readline("Enter my name: ")

cat("Welcome to my domian" , name)
# Out:
# Enter my name: matthew
# Welcome to my domian matthew

# %% [markdown]
# 5. Decision Making

# %%
grade <- 50

if (grade > 75){
  print("Passed")
}else{
  print("Failed")
}
# Out:
# [1] "Failed"

# %% [markdown]
# 6. Loop

# %%
for (i in 1:5){
  print(i)
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %% [markdown]
# 7. Funtion

# %%
addNum <- function(a,b){
  return (a+b)
}
addNum(a,b)
# Out:
# [1] 59

# %% [markdown]
# 8. Vectors

# %%
grades <- c(89,78,90,68,72)

grades

mean(grades)
min(grades)
max(grades)
median(grades)
length(grades)
summary(grades)
# Out:
# [1] 89 78 90 68 72
# [1] 79.4
# [1] 68
# [1] 90
# [1] 78
# [1] 5
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    68.0    72.0    78.0    79.4    89.0    90.0

# %% [markdown]
# 9. matrices

# %%
A <- matrix(c(3,2,4,5,6,7), nrow=3)
A
# Out:
#      [,1] [,2]
# [1,] 3    5
# [2,] 2    6
# [3,] 4    7

# %% [markdown]
# 10. List

# %%
student <- list(
  name = "Matthew",
  Course = "BSCS",
  Section = "3A",
  FavAnime = "CSM"
)

student
# Out:
# $name
# [1] "Matthew"
#
# $Course
# [1] "BSCS"
#
# $Section
# [1] "3A"
#
# $FavAnime
# [1] "CSM"

# %% [markdown]
# 11. Dataframe

# %%
mgakakilala <- data.frame(
  name = c ("MAT","GElO","AVI"),
  course = c ("IT","ComSci","IT"),
  favAnime = c ("CSM","JJK","Death Note"),
  grades = c ("85","75","90")
)

mgakakilala
# Out:
#   name course favAnime   grades
# 1 MAT  IT     CSM        85
# 2 GElO ComSci JJK        75
# 3 AVI  IT     Death Note 90

# %% [markdown]
# 12. write to CSV

# %%
write.csv(mgakakilala,"students.csv")

# %% [markdown]
# 13. read CSV file

# %%
data <- read.csv("students.csv")
